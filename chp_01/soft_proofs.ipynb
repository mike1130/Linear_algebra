# %% [markdown]
# # 1. Mathematical Proof vs Intuition from Coding
#
# How do you understand math?
# * _Rigorous proofs_: A proof in mathematics is a sequence of statements shpowing that a set of assumptions leads to a logical conclusion.
#
# * _Visualizations and examples_: clearly written explanations, diagrams, and numerical examples help you gain intuition for concepts and operations. __soft proofs__ is mathematical intuition built from coding.

# %%
import numpy as np
print(f'Commutivity principle of multiplication')
for i in range(10):
    a = np.random.randn()
    b = np.random.randn()
    print(f'Test {i+1}: {a*b - b*a}')
# Out:
# Test 1: 0.0
# Test 2: 0.0
# Test 3: 0.0
# Test 4: 0.0
# Test 5: 0.0
# Test 6: 0.0
# Test 7: 0.0
# Test 8: 0.0
# Test 9: 0.0
# Test 10: 0.0
